# %% [markdown]
# # 02 – Data Cleaning & Feature Engineering
# ## Bank Customer Churn
#
# **Objective:** Clean data, create features, prepare train/test split for modeling.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Reproducibility
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

df = pd.read_csv('../data/raw/Churn_Modelling.csv')
df.head()

# %%
# Drop IDs / non-predictive columns (adapt to actual schema)
# df = df.drop(columns=['RowNumber', 'CustomerId', 'Surname'])

# Encode categoricals (Geography, Gender)
# le_geo = LabelEncoder()
# df['Geography_enc'] = le_geo.fit_transform(df['Geography'])
# df['Gender_enc'] = (df['Gender'] == 'Male').astype(int)

# Optional: tenure bands, balance segments
# df['TenureBand'] = pd.cut(df['Tenure'], bins=[0,2,5,8,11], labels=['0-2','3-5','6-8','9+'])

df.info()

# %%
# Train/test split (stratify on Exited)
# X = df.drop(columns=['Exited'])
# y = df['Exited']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=RANDOM_STATE)

# Scale numeric features if needed
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

# Save processed data for 03_analysis and Power BI
# df.to_csv('../data/processed/churn_cleaned.csv', index=False)

# %% [markdown]
# **Next:** `03_analysis.ipynb` – Logistic Regression, Random Forest, confusion matrix, feature importance.
